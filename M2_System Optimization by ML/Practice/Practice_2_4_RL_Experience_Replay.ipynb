# %% [markdown]
# <a href="https://colab.research.google.com/github/hrbae/LG_AI_training/blob/main/M2_System%20Optimization%20by%20ML/Practice/Practice_2_4_RL_Experience_Replay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install xvfb -y
# !apt-get install python-opengl -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 784 kB of archives.
# After this operation, 2,270 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.9 [784 kB]
# Fetched 784 kB in 1s (895 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.9_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.9) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.9) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   libgle3
# The following NEW packages will be installed:
#   python-opengl
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 496 kB of archives.
# After this operation, 5,416 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Fetched 496 kB in 1s (595 kB/s)
# Selecting previously unselected package python-opengl.
# (Reading database ... 155054 files and directories currently installed.)
# Preparing to unpack .../python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...

# %%
# !pip install gym
# !pip install pyvirtualdisplay
# !pip install piglet
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.7/dist-packages (2.2)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.7/dist-packages (from pyvirtualdisplay) (0.3)
# Requirement already satisfied: piglet in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: piglet-templates in /usr/local/lib/python3.7/dist-packages (from piglet) (1.2.0)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (1.6.3)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (2.0.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (2.4.7)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from piglet-templates->piglet) (21.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse->piglet-templates->piglet) (0.37.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from astunparse->piglet-templates->piglet) (1.15.0)

# %%
# 필요 라이브러리 호출 및 강화학습 환경 호출
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from PIL import Image
import time

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

env = gym.make('CartPole-v1').unwrapped

from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# %matplotlib inline

is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# 강화학습의 종류

# %% [markdown]
# ![캡쳐1.JPG](data:image/jpeg;base64,...)

# %%
# 강화학습에서 Memory 개념
state = env.reset()
action = env.action_space.sample()

print('State space: ', env.observation_space)
print('Initial state: ', state)
print('\nAction space: ', env.action_space)
print('Random action: ', action)
# Out:
# State space:  Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# Initial state:  [-0.0260252   0.04016616  0.03305387 -0.01268023]
#
# Action space:  Discrete(2)
# Random action:  0

# %% [markdown]
# 액션 (Action): 'CartPole'에서는 2개의 액션이 존재한다. 그리고 각각의 액션이 번호로 지정 되어 있다.
#
# $A = \{0, 1\}$
#
# Num	| Action
# ----|----
# 0 |	Push cart to the left
# 1 |	Push cart to the right

# %% [markdown]
# 상태 (State): 'CartPole'의 상태(State) $S$는 4개의 실수값의 배열로 되어 있다.
#
# $S = \begin{bmatrix}
# \{ s_{00}, s_{01}, \cdots\}, \\
# \{ s_{10}, s_{11}, \cdots \}, \\
# \{ s_{20}, s_{21}, \cdots \}, \\
# \{ s_{30}, s_{31}, \cdots \}
# \end{bmatrix}$
#
# Index | State                   | Min      | Max
# -----|-----------------|--------|------
# 0      | Cart Position       | -4.8    | 4.8
# 1       | Cart Velocity       | -Inf     | Inf
# 2      | Pole Angle           | -24 deg | 24 deg
# 3      | Pole Velocity At Tip | -Inf     | Inf
#
#
#
# > 4종류의 상태값 중에 하나가 0.0000001만 바뀌어도 상태가 바뀐다.

# %% [markdown]
# 보상 (Reward): 매 스텝(step)마다 +1을 보상 받는다. 종료 스텝(termination step)에도 +1을 보상 받음
#
# > 오래 버티면 높은 점수를 획득함

# %% [markdown]
# 3. Q-Learning
#
# > [DQN](https://www.youtube.com/watch?v=rQIShnTz1kU)

# %% [markdown]
# ![캡쳐2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Replay Memory 함수
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

class PrioritizedReplayMemory(object):
    def __init__(self, capacity, prob_alpha=0.6):
        self.prob_alpha = prob_alpha
        self.capacity   = capacity
        self.memory     = []
        self.position   = 0
        self.priorities = np.zeros((capacity,), dtype=np.float32)
    
    def push(self, state, action, next_state, reward):
        
        max_prio = self.priorities.max() if self.memory else 1.0
        
        if len(self.memory) < self.capacity:
            self.memory.append((state, action, next_state, reward))
        else:
            self.memory[self.position] = (state, action, next_state, reward)
        
        self.priorities[self.position] = max_prio
        self.position = (self.position + 1) % self.capacity
    
    def sample(self, batch_size, beta=0.4):
        if len(self.memory) == self.capacity:
            prios = self.priorities
        else:
            prios = self.priorities[:self.position]
        
        probs  = prios ** self.prob_alpha
        probs /= probs.sum()
        
        indices = np.random.choice(len(self.memory), batch_size, p=probs)
        samples = [self.memory[idx] for idx in indices]
        
        total    = len(self.memory)
        weights  = (total * probs[indices]) ** (-beta)
        weights /= weights.max()
        weights  = np.array(weights, dtype=np.float32)
        
        batch       = zip(*samples)
        states      = np.concatenate(batch[0])
        actions     = batch[1]
        rewards     = batch[2]
        next_states = np.concatenate(batch[3])
        
        return state, action, next_state, reward, indices, weights
    
    def update_priorities(self, batch_indices, batch_priorities):
        for idx, prio in zip(batch_indices, batch_priorities):
            self.priorities[idx] = prio

    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):

    def __init__(self, h, w):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=5, stride=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=2)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=2)
        self.bn3 = nn.BatchNorm2d(32)

        def conv2d_size_out(size, kernel_size = 5, stride = 2):
            return (size - (kernel_size - 1) - 1) // stride  + 1
        convw = conv2d_size_out(conv2d_size_out(conv2d_size_out(w)))
        convh = conv2d_size_out(conv2d_size_out(conv2d_size_out(h)))
        linear_input_size = convw * convh * 32
        self.head = nn.Linear(linear_input_size, 2)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        return self.head(x.view(x.size(0), -1))

# %%
resize = T.Compose([T.ToPILImage(),
                    T.Resize(40, interpolation=Image.CUBIC),
                    T.ToTensor()])


def get_cart_location(screen_width):
    world_width = env.x_threshold *2
    scale = screen_width / world_width
    return int(env.state[0] * scale + screen_width / 1.0)  # MIDDLE OF CART

def get_screen():
    # Returned screen requested by gym is 400x600x3, but is sometimes larger
    # such as 800x1200x3. Transpose it into torch order (CHW).
    screen = env.render(mode='rgb_array').transpose((2, 0, 1))
    # Cart is in the lower half, so strip off the top and bottom of the screen
    _, screen_height, screen_width = screen.shape
    screen = screen[:, int(screen_height*0.4):int(screen_height * 0.8)]
    view_width = int(screen_width * 2)
    cart_location = get_cart_location(screen_width)
    if cart_location < view_width // 2:
        slice_range = slice(view_width)
    elif cart_location > (screen_width - view_width // 2):
        slice_range = slice(-view_width, None)
    else:
        slice_range = slice(cart_location - view_width // 2,
                            cart_location + view_width // 2)
    # Strip off the edges, so that we have a square image centered on a cart
    screen = screen[:, :, slice_range]
    # Convert to float, rescale, convert to torch tensor
    # (this doesn't require a copy)
    screen = np.ascontiguousarray(screen, dtype=np.float32) / 255
    screen = torch.from_numpy(screen)
    # Resize, and add a batch dimension (BCHW)
    return resize(screen).unsqueeze(0).to(device)


env.reset()
plt.figure()
plt.imshow(get_screen().cpu().squeeze(0).permute(1, 2, 0).numpy(),
           interpolation='none')
plt.title('Example extracted screen')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:281: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "

# %%
BATCH_SIZE = 256
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10

# Get screen size so that we can initialize layers correctly based on shape
# returned from AI gym. Typical dimensions at this point are close to 3x40x90
# which is the result of a clamped and down-scaled render buffer in get_screen()
init_screen = get_screen()
_, _, screen_height, screen_width = init_screen.shape

policy_net = DQN(screen_height, screen_width).to(device)
target_net = DQN(screen_height, screen_width).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr = 0.001)
memory = ReplayMemory(10000)

steps_done = 0

def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1): 각 행의 열에 대해 가장 큰 값을 반환
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(2)]], device=device, dtype=torch.long)


episode_durations = []

def plot_durations():
    plt.figure(2)
    plt.clf()
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())

    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        display.clear_output(wait=True)
        display.display(plt.gcf())

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions))

    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.uint8)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    state_action_values = policy_net(state_batch).gather(1, action_batch)

    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    
    # expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Huber Loss
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
torch.manual_seed(10)
num_episodes = 5
max_step = []
for i_episode in range(num_episodes):
    print('{}번째 에피소드 학습 시작'.format(i_episode+1))
    for i in range(3):
      time.sleep(1)
      print('{}초 전 '.format(i+1))
    # Initialize the environment and state
    env.reset()
    last_screen = get_screen()
    current_screen = get_screen()
    state = current_screen - last_screen
    for idx, t in enumerate(count()):

        # Select and perform an action
        action = select_action(state)
        _, reward, done, _ = env.step(action.item())
        reward = torch.tensor([reward], device=device)

        plt.figure()
        plt.imshow(get_screen().cpu().squeeze(0).permute(1, 2, 0).numpy(),
                  interpolation='none')
        plt.show()

        # Observe new state
        last_screen = current_screen
        current_screen = get_screen()
        if not done:
            next_state = current_screen - last_screen
        else:
            next_state = None

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Optimizating network
        optimize_model()
        
        if done:
            episode_durations.append(t + 1)
            #plot_durations()
            break
        
    print('{}번째 에피소드 학습 결과: {}번 생존'.format(i_episode+1,idx+1))
    max_step.append(idx+1)

    # Update the target network
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())
# Out:
# 2번째 에피소드 학습 결과: 12번 생존
# 3번째 에피소드 학습 시작
# 1초 전
# 2초 전
# 3초 전
# 3번째 에피소드 학습 결과: 12번 생존
# 4번째 에피소드 학습 시작
# 1초 전
# 2초 전
# 3초 전
# 4번째 에피소드 학습 결과: 20번 생존
# 5번째 에피소드 학습 시작
# 1초 전
# 2초 전
# 3초 전
# 5번째 에피소드 학습 결과: 36번 생존

# %% [markdown]
# *   Experience Replay 기법을 사용 하였을 때

# %%
torch.manual_seed(10)
num_episodes = 300
max_step = []
for i_episode in range(num_episodes):
    #print('{}번째 에피소드 학습 시작'.format(i_episode+1))
    '''
    for i in range(5):
      time.sleep(1)
      print('{}초 전 '.format(i+1))
    '''
    # Initialize the environment and state
    env.reset()
    last_screen = get_screen()
    current_screen = get_screen()
    state = current_screen - last_screen
    for idx, t in enumerate(count()):

        # Select and perform an action
        action = select_action(state)
        _, reward, done, _ = env.step(action.item())
        reward = torch.tensor([reward], device=device)
        '''
        plt.figure()
        plt.imshow(get_screen().cpu().squeeze(0).permute(1, 2, 0).numpy(),
                  interpolation='none')
        plt.show()
        '''
        # Observe new state
        last_screen = current_screen
        current_screen = get_screen()
        if not done:
            next_state = current_screen - last_screen
        else:
            next_state = None

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Optimizating network
        optimize_model()
        
        if done:
            episode_durations.append(t + 1)
            #plot_durations()
            break
        
    print('{}번째 에피소드 학습 결과: {}번 생존'.format(i_episode+1,idx+1))
    #time.sleep(5)
    max_step.append(idx+1)

    # Update the target network
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.render()
env.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/IndexingUtils.h:30.)
# 1번째 에피소드 학습 결과: 14번 생존
# 2번째 에피소드 학습 결과: 30번 생존
# 3번째 에피소드 학습 결과: 10번 생존
# 4번째 에피소드 학습 결과: 33번 생존
# 5번째 에피소드 학습 결과: 28번 생존
# 6번째 에피소드 학습 결과: 19번 생존
# 7번째 에피소드 학습 결과: 31번 생존
# 8번째 에피소드 학습 결과: 19번 생존
# 9번째 에피소드 학습 결과: 30번 생존
# 10번째 에피소드 학습 결과: 12번 생존
# 11번째 에피소드 학습 결과: 18번 생존
# 12번째 에피소드 학습 결과: 9번 생존
# 13번째 에피소드 학습 결과: 18번 생존
# 14번째 에피소드 학습 결과: 13번 생존
# 15번째 에피소드 학습 결과: 17번 생존
# 16번째 에피소드 학습 결과: 25번 생존
# 17번째 에피소드 학습 결과: 35번 생존
# 18번째 에피소드 학습 결과: 17번 생존
# 19번째 에피소드 학습 결과: 49번 생존
# 20번째 에피소드 학습 결과: 16번 생존
# 21번째 에피소드 학습 결과: 20번 생존
# 22번째 에피소드 학습 결과: 18번 생존
# 23번째 에피소드 학습 결과: 40번 생존
# 24번째 에피소드 학습 결과: 40번 생존
# 25번째 에피소드 학습 결과: 37번 생존
# 26번째 에피소드 학습 결과: 15번 생존
# 27번째 에피소드 학습 결과: 9번 생존
# 28번째 에피소드 학습 결과: 15번 생존
# 29번째 에피소드 학습 결과: 15번 생존
# 30번째 에피소드 학습 결과: 38번 생존
# 31번째 에피소드 학습 결과: 12번 생존
# 32번째 에피소드 학습 결과: 17번 생존
# 33번째 에피소드 학습 결과: 38번 생존
# 34번째 에피소드 학습 결과: 10번 생존
# 35번째 에피소드 학습 결과: 40번 생존
# 36번째 에피소드 학습 결과: 19번 생존
# 37번째 에피소드 학습 결과: 20번 생존
# 38번째 에피소드 학습 결과: 21번 생존
# 39번째 에피소드 학습 결과: 30번 생존
# 40번째 에피소드 학습 결과: 23번 생존
# 41번째 에피소드 학습 결과: 27번 생존
# 42번째 에피소드 학습 결과: 14번 생존
# 43번째 에피소드 학습 결과: 29번 생존
# 44번째 에피소드 학습 결과: 21번 생존
# 45번째 에피소드 학습 결과: 42번 생존
# 46번째 에피소드 학습 결과: 17번 생존
# 47번째 에피소드 학습 결과: 64번 생존
# 48번째 에피소드 학습 결과: 17번 생존
# 49번째 에피소드 학습 결과: 29번 생존
# 50번째 에피소드 학습 결과: 28번 생존
# 51번째 에피소드 학습 결과: 47번 생존
# 52번째 에피소드 학습 결과: 32번 생존
# 53번째 에피소드 학습 결과: 28번 생존
# 54번째 에피소드 학습 결과: 17번 생존
# 55번째 에피소드 학습 결과: 20번 생존
# 56번째 에피소드 학습 결과: 58번 생존
# 57번째 에피소드 학습 결과: 17번 생존
# 58번째 에피소드 학습 결과: 17번 생존
# 59번째 에피소드 학습 결과: 25번 생존
# 60번째 에피소드 학습 결과: 11번 생존
# 61번째 에피소드 학습 결과: 52번 생존
# 62번째 에피소드 학습 결과: 12번 생존
# 63번째 에피소드 학습 결과: 23번 생존
# 64번째 에피소드 학습 결과: 50번 생존
# 65번째 에피소드 학습 결과: 18번 생존
# 66번째 에피소드 학습 결과: 32번 생존
# 67번째 에피소드 학습 결과: 48번 생존
# 68번째 에피소드 학습 결과: 10번 생존
# 69번째 에피소드 학습 결과: 13번 생존
# 70번째 에피소드 학습 결과: 25번 생존
# 71번째 에피소드 학습 결과: 48번 생존
# 72번째 에피소드 학습 결과: 46번 생존
# 73번째 에피소드 학습 결과: 65번 생존
# 74번째 에피소드 학습 결과: 23번 생존
# 75번째 에피소드 학습 결과: 14번 생존
# 76번째 에피소드 학습 결과: 42번 생존
# 77번째 에피소드 학습 결과: 17번 생존
# 78번째 에피소드 학습 결과: 35번 생존
# 79번째 에피소드 학습 결과: 13번 생존
# 80번째 에피소드 학습 결과: 16번 생존
# 81번째 에피소드 학습 결과: 11번 생존
# 82번째 에피소드 학습 결과: 17번 생존
# 83번째 에피소드 학습 결과: 8번 생존
# 84번째 에피소드 학습 결과: 34번 생존
# 85번째 에피소드 학습 결과: 31번 생존
# 86번째 에피소드 학습 결과: 15번 생존
# 87번째 에피소드 학습 결과: 14번 생존
# 88번째 에피소드 학습 결과: 20번 생존
# 89번째 에피소드 학습 결과: 39번 생존
# 90번째 에피소드 학습 결과: 22번 생존
# 91번째 에피소드 학습 결과: 31번 생존
# 92번째 에피소드 학습 결과: 33번 생존
# 93번째 에피소드 학습 결과: 11번 생존
# 94번째 에피소드 학습 결과: 14번 생존
# 95번째 에피소드 학습 결과: 9번 생존
# 96번째 에피소드 학습 결과: 13번 생존
# 97번째 에피소드 학습 결과: 10번 생존
# 98번째 에피소드 학습 결과: 12번 생존
# 99번째 에피소드 학습 결과: 9번 생존
# 100번째 에피소드 학습 결과: 13번 생존
# 101번째 에피소드 학습 결과: 16번 생존
# 102번째 에피소드 학습 결과: 9번 생존
# 103번째 에피소드 학습 결과: 11번 생존
# 104번째 에피소드 학습 결과: 9번 생존
# 105번째 에피소드 학습 결과: 8번 생존
# 106번째 에피소드 학습 결과: 9번 생존
# 107번째 에피소드 학습 결과: 14번 생존
# 108번째 에피소드 학습 결과: 10번 생존
# 109번째 에피소드 학습 결과: 11번 생존
# 110번째 에피소드 학습 결과: 11번 생존
# 111번째 에피소드 학습 결과: 11번 생존
# 112번째 에피소드 학습 결과: 10번 생존
# 113번째 에피소드 학습 결과: 29번 생존
# 114번째 에피소드 학습 결과: 33번 생존
# 115번째 에피소드 학습 결과: 11번 생존
# 116번째 에피소드 학습 결과: 11번 생존
# 117번째 에피소드 학습 결과: 29번 생존
# 118번째 에피소드 학습 결과: 12번 생존
# 119번째 에피소드 학습 결과: 8번 생존
# 120번째 에피소드 학습 결과: 47번 생존
# 121번째 에피소드 학습 결과: 9번 생존
# 122번째 에피소드 학습 결과: 19번 생존
# 123번째 에피소드 학습 결과: 14번 생존
# 124번째 에피소드 학습 결과: 15번 생존
# 125번째 에피소드 학습 결과: 25번 생존
# 126번째 에피소드 학습 결과: 9번 생존
# 127번째 에피소드 학습 결과: 10번 생존
# 128번째 에피소드 학습 결과: 13번 생존
# 129번째 에피소드 학습 결과: 11번 생존
# 130번째 에피소드 학습 결과: 28번 생존
# 131번째 에피소드 학습 결과: 11번 생존
# 132번째 에피소드 학습 결과: 8번 생존
# 133번째 에피소드 학습 결과: 42번 생존
# 134번째 에피소드 학습 결과: 11번 생존
# 135번째 에피소드 학습 결과: 15번 생존
# 136번째 에피소드 학습 결과: 42번 생존
# 137번째 에피소드 학습 결과: 20번 생존
# 138번째 에피소드 학습 결과: 31번 생존
# 139번째 에피소드 학습 결과: 14번 생존
# 140번째 에피소드 학습 결과: 17번 생존
# 141번째 에피소드 학습 결과: 31번 생존
# 142번째 에피소드 학습 결과: 12번 생존
# 143번째 에피소드 학습 결과: 12번 생존
# 144번째 에피소드 학습 결과: 15번 생존
# 145번째 에피소드 학습 결과: 14번 생존
# 146번째 에피소드 학습 결과: 48번 생존
# 147번째 에피소드 학습 결과: 43번 생존
# 148번째 에피소드 학습 결과: 46번 생존
# 149번째 에피소드 학습 결과: 22번 생존
# 150번째 에피소드 학습 결과: 50번 생존
# 151번째 에피소드 학습 결과: 9번 생존
# 152번째 에피소드 학습 결과: 12번 생존
# 153번째 에피소드 학습 결과: 27번 생존
# 154번째 에피소드 학습 결과: 33번 생존
# 155번째 에피소드 학습 결과: 33번 생존
# 156번째 에피소드 학습 결과: 80번 생존
# 157번째 에피소드 학습 결과: 55번 생존
# 158번째 에피소드 학습 결과: 66번 생존
# 159번째 에피소드 학습 결과: 33번 생존
# 160번째 에피소드 학습 결과: 22번 생존
# 161번째 에피소드 학습 결과: 31번 생존
# 162번째 에피소드 학습 결과: 40번 생존
# 163번째 에피소드 학습 결과: 26번 생존
# 164번째 에피소드 학습 결과: 58번 생존
# 165번째 에피소드 학습 결과: 56번 생존
# 166번째 에피소드 학습 결과: 61번 생존
# 167번째 에피소드 학습 결과: 55번 생존
# 168번째 에피소드 학습 결과: 49번 생존
# 169번째 에피소드 학습 결과: 59번 생존
# 170번째 에피소드 학습 결과: 14번 생존
# 171번째 에피소드 학습 결과: 57번 생존
# 172번째 에피소드 학습 결과: 38번 생존
# 173번째 에피소드 학습 결과: 28번 생존
# 174번째 에피소드 학습 결과: 87번 생존
# 175번째 에피소드 학습 결과: 39번 생존
# 176번째 에피소드 학습 결과: 77번 생존
# 177번째 에피소드 학습 결과: 41번 생존
# 178번째 에피소드 학습 결과: 29번 생존
# 179번째 에피소드 학습 결과: 51번 생존
# 180번째 에피소드 학습 결과: 64번 생존
# 181번째 에피소드 학습 결과: 87번 생존
# 182번째 에피소드 학습 결과: 22번 생존
# 183번째 에피소드 학습 결과: 83번 생존
# 184번째 에피소드 학습 결과: 28번 생존
# 185번째 에피소드 학습 결과: 36번 생존
# 186번째 에피소드 학습 결과: 81번 생존
# 187번째 에피소드 학습 결과: 36번 생존
# 188번째 에피소드 학습 결과: 28번 생존
# 189번째 에피소드 학습 결과: 69번 생존
# 190번째 에피소드 학습 결과: 29번 생존
# 191번째 에피소드 학습 결과: 30번 생존
# 192번째 에피소드 학습 결과: 48번 생존
# 193번째 에피소드 학습 결과: 84번 생존
# 194번째 에피소드 학습 결과: 55번 생존
# 195번째 에피소드 학습 결과: 87번 생존
# 196번째 에피소드 학습 결과: 35번 생존
# 197번째 에피소드 학습 결과: 38번 생존
# 198번째 에피소드 학습 결과: 28번 생존
# 199번째 에피소드 학습 결과: 38번 생존
# 200번째 에피소드 학습 결과: 35번 생존
# 201번째 에피소드 학습 결과: 10번 생존
# 202번째 에피소드 학습 결과: 56번 생존
# 203번째 에피소드 학습 결과: 44번 생존
# 204번째 에피소드 학습 결과: 39번 생존
# 205번째 에피소드 학습 결과: 29번 생존
# 206번째 에피소드 학습 결과: 69번 생존
# 207번째 에피소드 학습 결과: 33번 생존
# 208번째 에피소드 학습 결과: 20번 생존
# 209번째 에피소드 학습 결과: 56번 생존
# 210번째 에피소드 학습 결과: 34번 생존
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-cdf7011c4cfa> in <module>()
#      28         # Observe new state
#      29         last_screen = current_screen
# ---> 30         current_screen = get_screen()
#      31         if not done:
#      32             next_state = current_screen - last_screen
#
# <ipython-input-22-ee11419cd06d> in get_screen()
#      32     screen = torch.from_numpy(screen)
#      33     # Resize, and add a batch dimension (BCHW)
# ---> 34     return resize(screen).unsqueeze(0).to(device)
#      35
#      36
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      58     def __call__(self, img):
#      59         for t in self.transforms:
# ---> 60             img = t(img)
#      61         return img
#      62
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#     177
#     178         """
# --> 179         return F.to_pil_image(pic, self.mode)
#     180
#     181     def __repr__(self):
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py in to_pil_image(pic, mode)
#     242     if isinstance(pic, torch.Tensor):
#     243         if pic.is_floating_point() and mode != 'F':
# --> 244             pic = pic.mul(255).byte()
#     245         npimg = np.transpose(pic.cpu().numpy(), (1, 2, 0))
#     246
#
# KeyboardInterrupt:

# %%
plt.plot(max_step)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6e7da9628849> in <module>()
# ----> 1 plt.plot(max_step)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# *   Prioritized Experience Replay 기법을 사용한 경우

# %%
torch.manual_seed(10)
num_episodes = 300
max_step = []
for i_episode in range(num_episodes):
    #print('{}번째 에피소드 학습 시작'.format(i_episode+1))
    '''
    for i in range(5):
      time.sleep(1)
      print('{}초 전 '.format(i+1))
    '''
    # Initialize the environment and state
    env.reset()
    last_screen = get_screen()
    current_screen = get_screen()
    state = current_screen - last_screen
    for idx, t in enumerate(count()):

        # Select and perform an action
        action = select_action(state)
        _, reward, done, _ = env.step(action.item())
        reward = torch.tensor([reward], device=device)
        '''
        plt.figure()
        plt.imshow(get_screen().cpu().squeeze(0).permute(1, 2, 0).numpy(),
                  interpolation='none')
        plt.show()
        '''
        # Observe new state
        last_screen = current_screen
        current_screen = get_screen()
        if not done:
            next_state = current_screen - last_screen
        else:
            next_state = None

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Optimizating network
        optimize_model()
        
        if done:
            episode_durations.append(t + 1)
            #plot_durations()
            break
        
    print('{}번째 에피소드 학습 결과: {}번 생존'.format(i_episode+1,idx+1))
    #time.sleep(5)
    max_step.append(idx+1)

    # Update the target network
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.render()
env.close()

# %%
plt.plot(max_step)
